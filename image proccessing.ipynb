# %%
import cv2
import imageio

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
img=cv2.imread('fruits.jpeg')

# %%
plt.imshow(img)

# %%
convertedArray=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(convertedArray)

# %%
convertedArray.shape
# Out:
# (170, 297, 3)

# %%
plt.subplots(figsize=(15,10)
# Out:
#   Input In [12]
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
pic = imageio.imread('fruits.jpeg')

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for c, ax in zip(range(3), ax):
    split_img = np.zeros(pic.shape, dtype="uint8")

    split_img[:, :, c] = pic[:, :, c]

    ax.imshow(split_img)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,4))

# %%
histr = cv2.calcHist([convertedArray],[0],None,[256],[0,256])

# %%
plt.plot(histr); plt.show()

# %%
type(convertedArray)
# Out:
# numpy.ndarray

# %%
convertedArray.dtype
# Out:
# dtype('uint8')

# %%
convertedArray.min()
# Out:
# 0

# %%
convertedArray.max()
# Out:
# 255

# %%
convertedArray.shape
# Out:
# (170, 297, 3)

# %%
crp1 = convertedArray[:100, :200, :];
crp1.shape
plt.imshow(crp1);
plt.show()

# %%
plt.imshow(crp1)

# %%
crop2 = convertedArray[100:170,200:250,:]
plt.figure(figsize=(15,8));
plt.imshow(crop2)
plt.show()

# %%
plt.subplots(figsize=(15,10))
plt.imshow(convertedArray);
plt.axvline(125,color="red")
plt.axhline(84,color="violet")
plt.show()

# %%
plt.figure(figsize=(15,8));
plt.imshow(convertedArray[:100, :200, 0], cmap="Greys_r" );plt.show()

# %%
horSection = convertedArray[150,:,:]
plt.figure(figsize=(16,5));
plt.plot(horSection[:,0], label="R", color="#e74c3c")
plt.plot(horSection[:,1], label="G", color="#16a085")
plt.plot(horSection[:,2], label="B", color="#3498db")
plt.xlabel("x");
plt.legend();
plt.show()

# %%
verSection = convertedArray[:,200,:]
plt.figure(figsize=(16,5));
plt.plot(verSection[:,0], label="R", color="#e74c3c")
plt.plot(verSection[:,1], label="G", color="#16a085")
plt.plot(verSection[:,2], label="B", color="#3498db")
plt.xlabel("x");
plt.legend();
plt.show()
